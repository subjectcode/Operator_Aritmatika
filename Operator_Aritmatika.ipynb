# %% [markdown]
# <a href="https://colab.research.google.com/github/subjectcode/PPLG_Kev/blob/main/Operator_Aritmatika.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Operator**
#
# Operator adalah simbol aritmatika pada bahasa pemrograman Python atau bahasa lainnya, untuk melihat seluruh operator yang tersedia pada Python Anda dapat melihat table di bawah ini.
#
# ![image.png](data:image/png;base64,...)
#
#
# Mari kita membahas satu per satu operator pada bahasa pemrograman python

# %% [markdown]
# #  **Operator Aritmatika**
# Operator yang akan kita bahas adalah penambahan, pengurangan, perkalian, eksponensial, modulus, dan pembagian. Mari kita lihat operasi aritmatika sederhana pada bahasa pemrograman Python.

# %% [markdown]
# # **Pertambahan (Addition)**

# %%
# Pertambahan (Addition)



print("Pertambahan")
print("")

a = 9
b = 10
c = a+b
print(c)

print("")

# %% [markdown]
# # **Pengurangan (Subtraction)**

# %%
# Pengurangan (Subtraction)
print("Pengurangan")
print("")

e = 100
j = 90
k = e-j
print(k)

print("")
# Out:
# Pengurangan
#
# 10

# %% [markdown]
# # **Perkalian(Multiplication)**

# %%
# Perkalian(Multiplication)

print("Perkalian")
print("")

n = 2000
h = 1000

e = n*h
print(e)

print("")
# Out:
# Perkalian
#
# 2000000

# %% [markdown]
# # **Pembagian(Division)**

# %%
# Pembagian(Division)

print("Pembagian")
print("")

o = 100
j = 10
e = o/j
print(e)

print("")

# %% [markdown]
# # **Persen(Modulus)**

# %%
# persen(Modulus)

print("Persen")
print("")

i = 100
o = 10
e = i%o
print(e)

print("")

# %% [markdown]
# # **Exponentiation**

# %%
# Exponentiation

print("Exponentiation")
print("")


o = 5
i = 100
e = o**i
print(e)

print("")

# %% [markdown]
# # **Floor division**

# %%
# Floor division

print("Floor division")
print("")

j = 9
k = 4
e = j//k
print(e)

print("")
# Out:
# Floor division
#
# 2

# %% [markdown]
# # **Assignment**

# %%
# Assignment

print("Assignment")
print("")

t = 5
print(t)

print("")
# Out:
# Assignment
#
# 5

# %% [markdown]
# # **Addition shorthand**

# %%
# Addition shorthand

print("Addition shorthand")
print("")

g = 3
g+= 3
print(g)

print("")
# Out:
# Addition shorthand
#
# 6

# %% [markdown]
# # **Subtraction shorthand**

# %%
# Subtraction shorthand

print("Subtraction shorthand")
print("")

k = 3
k-= 3
print(k)

print("")
# Out:
# Subtraction shorthand
#
# 0

# %% [markdown]
# # **Multiplication shorthand**

# %%
# Multiplication shorthand

print("Multiplication shorthand")
print("")

j = 5
j*= 2
print(j)

print("")
# Out:
# Multiplication shorthand
#
# 10

# %% [markdown]
# # **Division shorthand**

# %%
# Division shorthand

print("Division shorthand")
print("")


k = 10
k/= 5
print(k)

print("")
# Out:
# Division shorthand
#
# 2.0

# %% [markdown]
# # **Operator pembanding**

# %% [markdown]
# # **Equal**

# %%
# Equal

print("Equal")
print("")


j = 5
k = 5
print(j==k)

print("")
# Out:
# Equal
#
# True

# %% [markdown]
# # **Not Equal**

# %%
# Not Equal

print("Not Equal")
print("")

k = 10
j = 10
print(k!=j)

print("")
# Out:
# Not Equal
#
# False

# %% [markdown]
# # **Greater than**

# %%
# Greater than

print("Greater than")
print("")

j = 4
k = 5
print(j>k)

print("")

# %% [markdown]
# # **Less than**

# %%
# Less than

print("Less than")
print("")

k = 1
j = 2
print(k<j)

print("")

# %% [markdown]
# # **Greater than or equal to**

# %%
# Greater than or equal to

print("Greater than or equal to")
print("")


j = 100
k = 40
print(j>=k)

print("")

# %% [markdown]
# # **Less than or equal to**

# %%
# Less than or equal to

print("Less than or equal to")
print("")


l = 10
k = 10
print(l<=k)
print("")
# Out:
# Less than or equal to
#
# True

# %% [markdown]
# # **Operator logika**

# %% [markdown]
# # **True if both statements are true**

# %%
# True if both statements are true

print("True if both statements are true")
print("")

k = 10
j = 50

print(k < 5 and j > 10)
print("")

# %% [markdown]
# # **True if either statement is true**

# %%
# True if either statement is true

print("True if either statement is true")
print("")

k = 10
j = 40

print(k < 10 or j > 5)

print("")

# %% [markdown]
# # **Reverses the result. if result is true then false and vice versa**

# %%
# Reverses the result. if result is true then false and vice versa

print("Reverses the result. if result is true then false and vice versa")
print("")

k = 10

print(k < 0)
print("")

# %% [markdown]
# # **Conditional Statement**
#
# Conditional statement digunakan untuk memeriksa suatu kondisi yang ditentukan sebelumnya apakah nilai nya True atau False.
# Sering kali ketika kita sedang mengembangkan suatu aplikasi, ada hal di mana kita perlu memeriksa suatu kondisi tertentu lalu melakukan perintah yang berbeda tergantung pada hasil sebelumnya. Dalam skenario seperti itu conditional statement akan sangat berguna. if, elif dan else adalah pernyataan kondisional yang digunakan dalam bahasa pemrograman Python.
# Dengan conditional statement, kita dapat membandingkan suatu variable dan memeriksanya apakah variable tersebut memiliki nilai atau merupakan suatu boolean, dan selanjutnya memeriksa apakah True atau False. Oleh karena itu, mari kita praktekan penggunaannya.

# %% [markdown]
# # **Kondisi pertama**
#
# Kita memiliki suatu integer dan tiga kondisi. Yang pertama adalah kondisi if untuk mengecek apakah nomor tersebut sama dengan 10. Yang kedua adalah kondisi elif. Disini kita akan memeriksa apakah nomor tersebut kurang dari 10. Yang terakhir adalah kondisi else. Kondisi ini akan tereksekusi jika kedua kondisi sebelumnya tidak memenuhi syarat.

# %%
angka = 5
if angka == 10:
    print("angka adalah 10")
elif angka < 10:
    print("angka adalah kurang dari 10")
else:
    print("angka adalah lebih dari 10")
"""
Output:
angka adalah kurang dari 10
"""
# Out:
# angka adalah kurang dari 10
# '\nOutput:\nangka adalah kurang dari 10\n'

# %% [markdown]
# Catatan: Tidak wajib untuk menggunakan dua kondisi sama-dengan di dalam kondisi if. Anda dapat melakukannya dengan elif.

# %% [markdown]
# # **Kondisi kedua**
#
# Pada kasus ini kita akan memiliki variabel boolean dan dua kondisi. Pada contoh sebelumnya ketika kita membahas mengenai boolean apakah benar atau salah? Saat ini kita akan menggunakannya kembali pada conditional statement.
#
# Jika anda_robot, lalu print "Ya, saya robot", selain itu print "bukan, saya manusia".

# %%
anda_robot = False
if anda_robot:
    print ("Ya, saya robot")
else:
    print ("bukan, saya manusia")

"""
Output:
bukan, saya manusia
"""
# Out:
# bukan, saya manusia
# '\nOutput:\nbukan, saya manusia\n'

# %% [markdown]
# # **Kondisi ketiga**
#
# Pada contoh ini kita akan membuat kondisi berkebalikan dari kondisi kedua dengan operator not.

# %%
anda_robot = False
if not anda_robot:
    print ("Ya, saya robot")
else:
    print ("bukan, saya manusia")

"""
Output
Ya, saya robot
"""

# %% [markdown]
# # **Kondisi ke empat**
#
# Disini kita akan mendeklarasikan data sebagai None, lalu memeriksanya jika data tersebut ada atau tidak.

# %%
data = None
if data:
    print ("data bukan none")
else:
    print ("data adalah none")

# %% [markdown]
# # **Kondisi kelima**
#
# Anda pun dapat menggunakan if dalam satu baris pada bahasa pemrograman Python. Syntax nya akan terlihat seperti pada:

# %%
a = 10
b = 5
if a > b: print("a lebih besar dari b")

"""
Output:
a lebih besar dari b
"""

# %% [markdown]
# # **Kondisi ke enam**
#
# Anda pun dapat menggunakan if else dalam satu baris, seperti pada contoh di bawah ini:

# %%
num = 5
print("Angka adalah lima ") if num == 5 else print("Angka bukan lima")

"""
Output:
Nomor adalah lima
"""

# %% [markdown]
# # **Kondisi ketujuh**
#
# Anda pun dapat menggunakan nested if-else statement, yaitu:

# %%
num = 25
if num > 10:
    print("Angka lebih besar dari 10")
    if num > 20:
        print("Angka lebih besar dari 20")
    if num > 30:
        print("Angka lebih besar dari 30")
else:
    print("Angka lebih kecil dari 10")

"""
Output:
Nomer lebih besar dari 10
Nomer lebih besar dari 20
"""

# %% [markdown]
# # **Kondisi kedelapan**
#
# Anda dapat pula mengunakan operator and pada conditional statement. Operator ini menyatakan jika kondisi 1 dan 2 keduanya adalah benar.

# %%
num = 10
if num > 5 and num < 15:
     print(num)
else:
     print("Angka bisa lebih kecil dari 5 atau lebih besar dari 15")

"""
Output:
10
Karena 10 adalah angka di antara 5 dan 15.
"""

# %% [markdown]
# # **Kondisi kesembilan**
#
# Anda pun dapat menggunakan operator or dalam pernyataan bersyarat. Hal ini untuk menyatakan bahwa jika salah satu kondisi 1 atau kondisi 2 benar, sehingga program akan di eksekusi.

# %%
num = 10
if num > 5 or num < 7:
     print(num)

"""
Output:
10
"""

# %% [markdown]
# Output num adalah 10, padahal pada statement kedua adalah kurang dari 7? Hal ini disebabkan oleh kondisi or. Sehingga, jika salah satu kondisi terpenuhi, maka program akan tetap berjalan.

# %% [markdown]
# # **For loops**
#
# Metode lain yang berguna dalam bahasa pemrograman Python adalah iterator. Hal ini sangat membantu jika Anda ingin melakukan sesuatu beberapa kali.

# %%
print("Hai")
print("Hai")
print("Hai")

# %% [markdown]
# Dapat dibayangkan jika kita ingin menulis kata "Hai" sebanyak seribu kali, tentu kode program kita akan sangat sulit untuk di baca, selain itu, kemungkinan terjadinya kesalahan sangat lah besar. Oleh karena itu, kita dapat menggunakan suatu cara yang disebut loop atau iterator. Ada dua cara untuk menjalankan perintah tersebut, yaitu dengan for atau while loop

# %%
for i in range(3):
   print("Hai")

"""
Output:
Hai
Hai
Hai
"""

# %%
for i in range(1,3):
   print("Hai")

"""
Output
Hai
Hai
"""

# %%
for i in range(3):
  print("Hai")
else:
  print("Selesai")

"""
Output
Hai
Hai
Hai
Selesai
"""

# %% [markdown]
# # **While loops**
#
# Dalam bahasa pemrograman Python, terdapat metode loop atau iterator yang lain, yaitu while loop. Kita pun dapat memberikan hasil yang sama seperti yang telah kita lakukan pada for loop dengan menggunakan while loop, seperti contoh di bawah ini:

# %%
i = 0
while i < 3:
  print("Angka", i)
  i += 1

"""
Output
Angka 0
Angka 1
Angka 2
"""

# %% [markdown]
# Perlu diperhatikan bahwa, setiap kali kita menggunakan perintah while loop. Kita harus menambahkan statement increment atau statement yang dapat menghentikan loop pada titik tertentu. Jika kita tidak menggunakannya, maka proses loop akan berjalan selama nya.

# %% [markdown]
# Cara lain untuk menghentikan loop adalah dengan menambahkan statement break di dalam while loop. Perintah ini akan menghentikan loop seperti pada contoh di bawah ini.

# %%
i = 0
while i < 3:
    if i == 3:
           break
    print("Angka", i)
    i += 1

"""
Output
Angka 0
Angka 1
Angka 2
"""
